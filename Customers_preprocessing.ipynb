# %%
import pandas as pd
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ---
# ## **Load Tables**

# %%
excel_file = pd.ExcelFile('Dataset.xlsx')
sheet_names = excel_file.sheet_names
sheet_names
# Out:
# ['Transactions', 'NewCustomerList', 'CustomerDemographic', 'CustomerAddress']

# %% [markdown]
# ---
# ## **CustomerDemographic Table**

# %% [markdown]
# #### **First Table (Customer Information):**
# * **customer_id:** Unique identifier for each customer.
# * **name:** Full name of the customer.
# * **gender:** The gender of the customer (e.g., Male, Female).
# * **past_3_years_bike_related_purchases:** The number of bike-related purchases made by the customer in the past three years.
# * **age:** The age of the customer.
# * **job_title:** The customer’s job or role in their profession.
# * **job_industry_category:** The industry in which the customer works (e.g., Health, Financial Services, IT).
# * **wealth_segment:** The wealth classification of the customer (e.g., Mass Customer, Affluent Customer).
# * **deceased_indicator:** Indicates whether the customer is deceased (Yes or No).
# * **owns_car:** Indicates if the customer owns a car (Yes or No).
# * **tenure:** The number of years the customer has been associated with the company or service.

# %%
CustomerDemographic_df = pd.read_excel(excel_file, sheet_name='CustomerDemographic')
CustomerDemographic_df
# Out:
#       customer_id      first_name  last_name  gender  \
# 0               1         Laraine  Medendorp       F
# 1               2             Eli    Bockman    Male
# 2               3           Arlin     Dearle    Male
# 3               4          Talbot        NaN    Male
# 4               5  Sheila-kathryn     Calton  Female
# ...           ...             ...        ...     ...
# 3995         3996         Rosalia   Halgarth  Female
# 3996         3997          Blanch     Nisuis  Female
# 3997         3998          Sarene    Woolley       U
# 3998         3999       Patrizius        NaN    Male
# 3999         4000           Kippy    Oldland    Male
#
#       past_3_years_bike_related_purchases                  DOB  \
# 0                                      93  1953-10-12 00:00:00
# 1                                      81  1980-12-16 00:00:00
# 2                                      61  1954-01-20 00:00:00
# 3                                      33  1961-10-03 00:00:00
# ...

# %%
CustomerDemographic_df.drop('default', axis=1, inplace=True)

# %%
CustomerDemographic_df.tail()
# Out:
#       customer_id first_name last_name  gender  \
# 3995         3996    Rosalia  Halgarth  Female
# 3996         3997     Blanch    Nisuis  Female
# 3997         3998     Sarene   Woolley       U
# 3998         3999  Patrizius       NaN    Male
# 3999         4000      Kippy   Oldland    Male
#
#       past_3_years_bike_related_purchases                  DOB  \
# 3995                                    8  1975-08-09 00:00:00
# 3996                                   87  2001-07-13 00:00:00
# 3997                                   60                  NaN
# 3998                                   11  1973-10-24 00:00:00
# 3999                                   76  1991-11-05 00:00:00
#
#                   job_title job_industry_category     wealth_segment  \
# 3995  VP Product Management                Health      Mass Customer
# 3996        Statistician II         Manufacturing     High Net Worth
# 3997      Assistant Manager                    IT     High Net Worth
# ...

# %% [markdown]
# ---
# ## **CustomerAddress Table**

# %% [markdown]
# #### **Second Table (Customer Address Information):**
# * **customer_id:** Unique identifier that corresponds to the same customer_id in the first table.
# * **address:** The full address of the customer.
# * **postcode:** The postal code for the customer’s address.
# * **state:** The state where the customer resides (e.g., New South Wales, Queensland, Victoria).
# * **country:** The country of the customer, which appears to be "Australia" for all entries.
# * **property_valuation:** A rating or numerical value representing the estimated value of the customer's property.

# %%
CustomerAddress_df = pd.read_excel(excel_file, sheet_name='CustomerAddress')
CustomerAddress_df
# Out:
#       customer_id                    address  postcode            state  \
# 0               1         060 Morning Avenue      2016  New South Wales
# 1               2        6 Meadow Vale Court      2153  New South Wales
# 2               4         0 Holy Cross Court      4211              QLD
# 3               5        17979 Del Mar Point      2448  New South Wales
# 4               6           9 Oakridge Court      3216              VIC
# ...           ...                        ...       ...              ...
# 3994         3999            1482 Hauk Trail      3064              VIC
# 3995         4000  57042 Village Green Point      4511              QLD
# 3996         4001     87 Crescent Oaks Alley      2756              NSW
# 3997         4002           8194 Lien Street      4032              QLD
# 3998         4003            320 Acker Drive      2251              NSW
#
#         country  property_valuation
# 0     Australia                  10
# ...

# %% [markdown]
# ---
# ## **Merge all Customer Details into a one table**

# %%
Customer_Details_df = pd.merge(CustomerDemographic_df, CustomerAddress_df, on='customer_id')
Customer_Details_df
# Out:
#       customer_id      first_name  last_name  gender  \
# 0               1         Laraine  Medendorp       F
# 1               2             Eli    Bockman    Male
# 2               4          Talbot        NaN    Male
# 3               5  Sheila-kathryn     Calton  Female
# 4               6            Curr  Duckhouse    Male
# ...           ...             ...        ...     ...
# 3991         3996         Rosalia   Halgarth  Female
# 3992         3997          Blanch     Nisuis  Female
# 3993         3998          Sarene    Woolley       U
# 3994         3999       Patrizius        NaN    Male
# 3995         4000           Kippy    Oldland    Male
#
#       past_3_years_bike_related_purchases                  DOB  \
# 0                                      93  1953-10-12 00:00:00
# 1                                      81  1980-12-16 00:00:00
# 2                                      33  1961-10-03 00:00:00
# 3                                      56  1977-05-13 00:00:00
# ...

# %% [markdown]
# ---
# ## **NewCustomerList Table**

# %%
NewCustomerList_df = pd.read_excel(excel_file, sheet_name='NewCustomerList')
NewCustomerList_df.tail()
# Out:
#     first_name  last_name  gender  past_3_years_bike_related_purchases  \
# 995  Ferdinand  Romanetti    Male                                   60
# 996       Burk    Wortley    Male                                   22
# 997   Melloney      Temby  Female                                   17
# 998     Dickie    Cubbini    Male                                   30
# 999      Sylas    Duffill    Male                                   56
#
#             DOB                     job_title job_industry_category  \
# 995  1959-10-07                     Paralegal    Financial Services
# 996  2001-10-17        Senior Sales Associate                Health
# 997  1954-10-05  Budget/Accounting Analyst IV    Financial Services
# 998  1952-12-17             Financial Advisor    Financial Services
# 999  1955-10-02           Staff Accountant IV              Property
#
#         wealth_segment deceased_indicator owns_car  ...  state    country  \
# ...

# %%
NewCustomerList_df.columns
# Out:
# Index(['first_name', 'last_name', 'gender',
#        'past_3_years_bike_related_purchases', 'DOB', 'job_title',
#        'job_industry_category', 'wealth_segment', 'deceased_indicator',
#        'owns_car', 'tenure', 'address', 'postcode', 'state', 'country',
#        'property_valuation', 'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18',
#        'Unnamed: 19', 'Unnamed: 20', 'Rank', 'Value'],
#       dtype='object')

# %%
NewCustomerList_df['tenure']
# Out:
# 0      14
# 1      16
# 2      10
# 3       5
# 4      19
#        ..
# 995     9
# 996     6
# 997    15
# 998    19
# 999    14
# Name: tenure, Length: 1000, dtype: int64

# %% [markdown]
# **Invalid Tenure for New Customers:** The tenure column had unrealistic values, like 15 or 9 years, for new customers.
# * **Solution:** Corrected these values by filling the tenure column with 0 for all new customers to reflect their accurate status

# %%
NewCustomerList_df['tenure'] = 0

# %% [markdown]
# ---
# ## **Add ID to New Customer Table**

# %%
NewCustomerList_df['customer_id'] = list(range(4001, 5001))
NewCustomerList_df.head()
# Out:
#   first_name  last_name  gender  past_3_years_bike_related_purchases  \
# 0    Chickie    Brister    Male                                   86
# 1      Morly     Genery    Male                                   69
# 2    Ardelis  Forrester  Female                                   10
# 3     Lucine      Stutt  Female                                   64
# 4    Melinda     Hadlee  Female                                   34
#
#                    DOB                   job_title job_industry_category  \
# 0           1957-07-12             General Manager         Manufacturing
# 1           1970-03-22         Structural Engineer              Property
# 2  1974-08-28 00:00:00      Senior Cost Accountant    Financial Services
# 3           1979-01-28  Account Representative III         Manufacturing
# 4           1965-09-21           Financial Analyst    Financial Services
#
#       wealth_segment deceased_indicator owns_car  ...    country  \
# ...

# %% [markdown]
# ---
# ## **Merge all Customers into one table**

# %%
Customer_Details_df.columns
# Out:
# Index(['customer_id', 'first_name', 'last_name', 'gender',
#        'past_3_years_bike_related_purchases', 'DOB', 'job_title',
#        'job_industry_category', 'wealth_segment', 'deceased_indicator',
#        'owns_car', 'tenure', 'address', 'postcode', 'state', 'country',
#        'property_valuation'],
#       dtype='object')

# %%
NewCustomerList_df.columns
# Out:
# Index(['first_name', 'last_name', 'gender',
#        'past_3_years_bike_related_purchases', 'DOB', 'job_title',
#        'job_industry_category', 'wealth_segment', 'deceased_indicator',
#        'owns_car', 'tenure', 'address', 'postcode', 'state', 'country',
#        'property_valuation', 'Unnamed: 16', 'Unnamed: 17', 'Unnamed: 18',
#        'Unnamed: 19', 'Unnamed: 20', 'Rank', 'Value', 'customer_id'],
#       dtype='object')

# %% [markdown]
# ### **Select The Common columns**

# %%
NewCustomerList_df = NewCustomerList_df[['customer_id', 'first_name', 'last_name', 'gender',
       'past_3_years_bike_related_purchases', 'DOB', 'job_title',
       'job_industry_category', 'wealth_segment', 'deceased_indicator',
       'owns_car', 'tenure', 'address', 'postcode', 'state', 'country',
       'property_valuation']]

NewCustomerList_df.head()
# Out:
#    customer_id first_name  last_name  gender  \
# 0         4001    Chickie    Brister    Male
# 1         4002      Morly     Genery    Male
# 2         4003    Ardelis  Forrester  Female
# 3         4004     Lucine      Stutt  Female
# 4         4005    Melinda     Hadlee  Female
#
#    past_3_years_bike_related_purchases                  DOB  \
# 0                                   86           1957-07-12
# 1                                   69           1970-03-22
# 2                                   10  1974-08-28 00:00:00
# 3                                   64           1979-01-28
# 4                                   34           1965-09-21
#
#                     job_title job_industry_category     wealth_segment  \
# 0             General Manager         Manufacturing      Mass Customer
# 1         Structural Engineer              Property      Mass Customer
# 2      Senior Cost Accountant    Financial Services  Affluent Customer
# ...

# %% [markdown]
# ### **Merging**

# %%
All_Customer_Details_df = pd.concat([Customer_Details_df, NewCustomerList_df], axis=0)
All_Customer_Details_df = All_Customer_Details_df.reset_index(drop=True)
All_Customer_Details_df
# Out:
#       customer_id      first_name  last_name  gender  \
# 0               1         Laraine  Medendorp       F
# 1               2             Eli    Bockman    Male
# 2               4          Talbot        NaN    Male
# 3               5  Sheila-kathryn     Calton  Female
# 4               6            Curr  Duckhouse    Male
# ...           ...             ...        ...     ...
# 4991         4996       Ferdinand  Romanetti    Male
# 4992         4997            Burk    Wortley    Male
# 4993         4998        Melloney      Temby  Female
# 4994         4999          Dickie    Cubbini    Male
# 4995         5000           Sylas    Duffill    Male
#
#       past_3_years_bike_related_purchases                  DOB  \
# 0                                      93  1953-10-12 00:00:00
# 1                                      81  1980-12-16 00:00:00
# 2                                      33  1961-10-03 00:00:00
# 3                                      56  1977-05-13 00:00:00
# ...

# %% [markdown]
# ---
# ## **Customers Details Data Exploration**

# %%
All_Customer_Details_df.head()
# Out:
#    customer_id      first_name  last_name  gender  \
# 0            1         Laraine  Medendorp       F
# 1            2             Eli    Bockman    Male
# 2            4          Talbot        NaN    Male
# 3            5  Sheila-kathryn     Calton  Female
# 4            6            Curr  Duckhouse    Male
#
#    past_3_years_bike_related_purchases                  DOB  \
# 0                                   93  1953-10-12 00:00:00
# 1                                   81  1980-12-16 00:00:00
# 2                                   33  1961-10-03 00:00:00
# 3                                   56  1977-05-13 00:00:00
# 4                                   35  1966-09-16 00:00:00
#
#                 job_title job_industry_category     wealth_segment  \
# 0     Executive Secretary                Health      Mass Customer
# 1  Administrative Officer    Financial Services      Mass Customer
# 2                     NaN                    IT      Mass Customer
# ...

# %% [markdown]
# ##### Check for Duplicates

# %%
All_Customer_Details_df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ##### Validity

# %%
All_Customer_Details_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4996 entries, 0 to 4995
# Data columns (total 17 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   customer_id                          4996 non-null   int64
#  1   first_name                           4996 non-null   object
#  2   last_name                            4842 non-null   object
#  3   gender                               4996 non-null   object
#  4   past_3_years_bike_related_purchases  4996 non-null   int64
#  5   DOB                                  4892 non-null   object
#  6   job_title                            4386 non-null   object
#  7   job_industry_category                4176 non-null   object
#  8   wealth_segment                       4996 non-null   object
#  9   deceased_indicator                   4996 non-null   object
#  10  owns_car                             4996 non-null   object
# ...

# %%
All_Customer_Details_df['DOB'] = pd.to_datetime(All_Customer_Details_df['DOB'])

# %%
from datetime import datetime

today_data = datetime(2017, 12, 31)
today_data
# Out:
# datetime.datetime(2017, 12, 31, 0, 0)

# %%
All_Customer_Details_df['age'] = (today_data - All_Customer_Details_df['DOB']).dt.days // 365
All_Customer_Details_df.drop('DOB', axis=1, inplace=True)
All_Customer_Details_df.head()
# Out:
#    customer_id      first_name  last_name  gender  \
# 0            1         Laraine  Medendorp       F
# 1            2             Eli    Bockman    Male
# 2            4          Talbot        NaN    Male
# 3            5  Sheila-kathryn     Calton  Female
# 4            6            Curr  Duckhouse    Male
#
#    past_3_years_bike_related_purchases               job_title  \
# 0                                   93     Executive Secretary
# 1                                   81  Administrative Officer
# 2                                   33                     NaN
# 3                                   56           Senior Editor
# 4                                   35                     NaN
#
#   job_industry_category     wealth_segment deceased_indicator owns_car  \
# 0                Health      Mass Customer                  N      Yes
# 1    Financial Services      Mass Customer                  N      Yes
# ...

# %%
All_Customer_Details_df.head()
# Out:
#    customer_id      first_name  last_name  gender  \
# 0            1         Laraine  Medendorp       F
# 1            2             Eli    Bockman    Male
# 2            4          Talbot        NaN    Male
# 3            5  Sheila-kathryn     Calton  Female
# 4            6            Curr  Duckhouse    Male
#
#    past_3_years_bike_related_purchases               job_title  \
# 0                                   93     Executive Secretary
# 1                                   81  Administrative Officer
# 2                                   33                     NaN
# 3                                   56           Senior Editor
# 4                                   35                     NaN
#
#   job_industry_category     wealth_segment deceased_indicator owns_car  \
# 0                Health      Mass Customer                  N      Yes
# 1    Financial Services      Mass Customer                  N      Yes
# ...

# %%
All_Customer_Details_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4996 entries, 0 to 4995
# Data columns (total 17 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   customer_id                          4996 non-null   int64
#  1   first_name                           4996 non-null   object
#  2   last_name                            4842 non-null   object
#  3   gender                               4996 non-null   object
#  4   past_3_years_bike_related_purchases  4996 non-null   int64
#  5   job_title                            4386 non-null   object
#  6   job_industry_category                4176 non-null   object
#  7   wealth_segment                       4996 non-null   object
#  8   deceased_indicator                   4996 non-null   object
#  9   owns_car                             4996 non-null   object
#  10  tenure                               4909 non-null   float64
# ...

# %%
All_Customer_Details_df.describe(include='O').drop('count').T
# Out:
#                       unique                                   top  freq
# first_name              3726                                   Max     5
# last_name               4610                              Pristnor     3
# gender                     6                                Female  2548
# job_title                195  Business Systems Development Analyst    55
# job_industry_category      9                         Manufacturing   998
# wealth_segment             3                         Mass Customer  2505
# deceased_indicator         2                                     N  4994
# owns_car                   2                                   Yes  2514
# address                 4990               3 Mariners Cove Terrace     2
# state                      5                                   NSW  2558
# country                    1                             Australia  4996

# %%
All_Customer_Details_df['gender'].unique()
# Out:
# array(['F', 'Male', 'Female', 'U', 'Femal', 'M'], dtype=object)

# %%
All_Customer_Details_df['gender'].replace({'F':'Female', 'Femal':'Female', 'M':'Male', 'U':'Unknown'}, inplace=True)
All_Customer_Details_df['gender'].unique()
# Out:
# array(['Female', 'Male', 'Unknown'], dtype=object)

# %%
cols = ['job_industry_category', 'wealth_segment', 'deceased_indicator', 'owns_car', 'state']

for col in cols:
    print(col)
    print(All_Customer_Details_df[col].unique())
    print(All_Customer_Details_df[col].value_counts())
    print('-'*40)
# Out:
# job_industry_category
# ['Health' 'Financial Services' 'IT' nan 'Retail' 'Argiculture' 'Property'
#  'Manufacturing' 'Telecommunications' 'Entertainment']
# job_industry_category
# Manufacturing         998
# Financial Services    976
# Health                754
# Retail                436
# Property              330
# IT                    273
# Entertainment         173
# Argiculture           139
# Telecommunications     97
# Name: count, dtype: int64
# ----------------------------------------
# wealth_segment
# ['Mass Customer' 'Affluent Customer' 'High Net Worth']
# wealth_segment
# Mass Customer        2505
# High Net Worth       1271
# Affluent Customer    1220
# Name: count, dtype: int64
# ----------------------------------------
# deceased_indicator
# ['N' 'Y']
# deceased_indicator
# N    4994
# Y       2
# Name: count, dtype: int64
# ----------------------------------------
# owns_car
# ['Yes' 'No']
# owns_car
# Yes    2514
# No     2482
# Name: count, dtype: int64
# ...

# %%
All_Customer_Details_df['deceased_indicator'].replace({'N':'No', 'Y':'Yes'}, inplace=True)
All_Customer_Details_df['deceased_indicator'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
All_Customer_Details_df['state'].unique()
# Out:
# array(['New South Wales', 'QLD', 'VIC', 'NSW', 'Victoria'], dtype=object)

# %%
All_Customer_Details_df['state'].replace({'NSW':'New South Wales', 'QLD':'Queensland', 'VIC':'Victoria'}, inplace=True)
All_Customer_Details_df['state'].unique()
# Out:
# array(['New South Wales', 'Queensland', 'Victoria'], dtype=object)

# %%
All_Customer_Details_df['building_number'] = All_Customer_Details_df['address'].str.split().str[0]

# %%
def street_split(address):
    address_list = address.split()[1:]
    str = ' '.join(address_list)
    return str

All_Customer_Details_df['street_name'] = All_Customer_Details_df['address'].map(street_split)
All_Customer_Details_df.head()
# Out:
#    customer_id      first_name  last_name  gender  \
# 0            1         Laraine  Medendorp  Female
# 1            2             Eli    Bockman    Male
# 2            4          Talbot        NaN    Male
# 3            5  Sheila-kathryn     Calton  Female
# 4            6            Curr  Duckhouse    Male
#
#    past_3_years_bike_related_purchases               job_title  \
# 0                                   93     Executive Secretary
# 1                                   81  Administrative Officer
# 2                                   33                     NaN
# 3                                   56           Senior Editor
# 4                                   35                     NaN
#
#   job_industry_category     wealth_segment deceased_indicator owns_car  \
# 0                Health      Mass Customer                 No      Yes
# 1    Financial Services      Mass Customer                 No      Yes
# ...

# %%
All_Customer_Details_df.drop('address', axis=1, inplace=True)

# %%
All_Customer_Details_df.describe(include='O').drop('count').T
# Out:
#                       unique                                   top  freq
# first_name              3726                                   Max     5
# last_name               4610                              Pristnor     3
# gender                     3                                Female  2550
# job_title                195  Business Systems Development Analyst    55
# job_industry_category      9                         Manufacturing   998
# wealth_segment             3                         Mass Customer  2505
# deceased_indicator         2                                    No  4994
# owns_car                   2                                   Yes  2514
# state                      3                       New South Wales  2644
# country                    1                             Australia  4996
# building_number         2682                                     2   113
# street_name             3932                         Montana Place     5

# %%
All_Customer_Details_df.describe().T
# Out:
#                                       count         mean          std     min  \
# customer_id                          4996.0  2502.490392  1442.381900     1.0
# past_3_years_bike_related_purchases  4996.0    49.072058    28.541125     0.0
# tenure                               4909.0     8.485231     6.627045     0.0
# postcode                             4996.0  2992.439151   845.758829  2000.0
# property_valuation                   4996.0     7.490592     2.812334     1.0
# age                                  4892.0    41.251022    13.994053    15.0
#
#                                          25%     50%      75%     max
# customer_id                          1253.75  2502.5  3751.25  5000.0
# past_3_years_bike_related_purchases    24.00    49.0    73.00    99.0
# tenure                                  2.00     8.0    14.00    22.0
# postcode                             2203.00  2768.0  3787.25  4883.0
# property_valuation                      6.00     8.0    10.00    12.0
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Select only numerical columns
num_columns = All_Customer_Details_df.select_dtypes(exclude='object')

n_cols = 4  # Set the number of columns per row to 4
n_rows = len(num_columns.columns) // n_cols + (len(num_columns.columns) % n_cols > 0)  # Calculate number of rows

# Create a grid for plots with 4 columns per row
fig, axes = plt.subplots(nrows=n_rows*2, ncols=n_cols, figsize=(5*n_cols, 5*n_rows*2))

# Flatten the axes array for easier indexing
axes = axes.flatten()

# Loop through the numerical columns and plot histogram and boxplot
for i, col in enumerate(num_columns.columns):
    # Plot histogram in the top half of the grid
    # sns.boxplot(df[col], orient='h')
    sns.histplot(num_columns[col], ax=axes[i*2], kde=True, color='brown')
    axes[i*2].set_title(f'Histogram of {col}')
    
    # Plot boxplot in the bottom half of the grid
    sns.boxplot(num_columns[col], orient='h', ax=axes[i*2 + 1])
    axes[i*2 + 1].set_title(f'Boxplot of {col}')

# Remove empty subplots (if any)
for j in range(i*2 + 2, len(axes)):
    fig.delaxes(axes[j])

# Adjust layout
plt.tight_layout()
plt.show()

# %%
All_Customer_Details_df[All_Customer_Details_df['age']==174.0]
# Out:
#     customer_id first_name last_name   gender  \
# 29           34   Jephthah  Bachmann  Unknown
#
#     past_3_years_bike_related_purchases        job_title  \
# 29                                   59  Legal Assistant
#
#    job_industry_category     wealth_segment deceased_indicator owns_car  \
# 29                    IT  Affluent Customer                 No       No
#
#     tenure  postcode       state    country  property_valuation    age  \
# 29    20.0      4005  Queensland  Australia                   8  174.0
#
#    building_number street_name
# 29             833  Luster Way

# %%
All_Customer_Details_df.drop(All_Customer_Details_df[All_Customer_Details_df['age']==174.0].index, inplace=True)

# %% [markdown]
# #### **Check For Missing Values**

# %%
All_Customer_Details_df.isnull().mean() * 100
# Out:
# customer_id                             0.000000
# first_name                              0.000000
# last_name                               3.083083
# gender                                  0.000000
# past_3_years_bike_related_purchases     0.000000
# job_title                              12.212212
# job_industry_category                  16.416416
# wealth_segment                          0.000000
# deceased_indicator                      0.000000
# owns_car                                0.000000
# tenure                                  1.741742
# postcode                                0.000000
# state                                   0.000000
# country                                 0.000000
# property_valuation                      0.000000
# age                                     2.082082
# building_number                         0.000000
# street_name                             0.000000
# dtype: float64

# %%
All_Customer_Details_df.isnull().sum()
# Out:
# customer_id                              0
# first_name                               0
# last_name                              154
# gender                                   0
# past_3_years_bike_related_purchases      0
# job_title                              610
# job_industry_category                  820
# wealth_segment                           0
# deceased_indicator                       0
# owns_car                                 0
# tenure                                  87
# postcode                                 0
# state                                    0
# country                                  0
# property_valuation                       0
# age                                    104
# building_number                          0
# street_name                              0
# dtype: int64

# %%
All_Customer_Details_df['name'] = All_Customer_Details_df['first_name'].fillna('').str.cat(All_Customer_Details_df['last_name'].fillna(''), sep=' ').str.strip()
All_Customer_Details_df.drop(['first_name', 'last_name'], axis=1, inplace=True)
All_Customer_Details_df.head()
# Out:
#    customer_id  gender  past_3_years_bike_related_purchases  \
# 0            1  Female                                   93
# 1            2    Male                                   81
# 2            4    Male                                   33
# 3            5  Female                                   56
# 4            6    Male                                   35
#
#                 job_title job_industry_category     wealth_segment  \
# 0     Executive Secretary                Health      Mass Customer
# 1  Administrative Officer    Financial Services      Mass Customer
# 2                     NaN                    IT      Mass Customer
# 3           Senior Editor                   NaN  Affluent Customer
# 4                     NaN                Retail     High Net Worth
#
#   deceased_indicator owns_car  tenure  postcode            state    country  \
# 0                 No      Yes    11.0      2016  New South Wales  Australia
# ...

# %%
All_Customer_Details_df.columns
# Out:
# Index(['customer_id', 'gender', 'past_3_years_bike_related_purchases',
#        'job_title', 'job_industry_category', 'wealth_segment',
#        'deceased_indicator', 'owns_car', 'tenure', 'postcode', 'state',
#        'country', 'property_valuation', 'age', 'building_number',
#        'street_name', 'name'],
#       dtype='object')

# %%
All_Customer_Details_df['job_title'].fillna('N/A', inplace = True)
All_Customer_Details_df['job_industry_category'].fillna('N/A', inplace = True)

# %%
All_Customer_Details_df.isnull().sum()
# Out:
# customer_id                              0
# gender                                   0
# past_3_years_bike_related_purchases      0
# job_title                                0
# job_industry_category                    0
# wealth_segment                           0
# deceased_indicator                       0
# owns_car                                 0
# tenure                                  87
# postcode                                 0
# state                                    0
# country                                  0
# property_valuation                       0
# age                                    104
# building_number                          0
# street_name                              0
# name                                     0
# dtype: int64

# %%
new_column_order = ['customer_id', 'name', 'gender', 'past_3_years_bike_related_purchases', 'age', 'job_title',
                    'job_industry_category', 'wealth_segment', 'deceased_indicator', 'owns_car', 'tenure',
                    'building_number', 'street_name', 'postcode', 'state', 'country', 'property_valuation']

All_Customer_Details_df = All_Customer_Details_df[new_column_order]
All_Customer_Details_df.head()
# Out:
#    customer_id                   name  gender  \
# 0            1      Laraine Medendorp  Female
# 1            2            Eli Bockman    Male
# 2            4                 Talbot    Male
# 3            5  Sheila-kathryn Calton  Female
# 4            6         Curr Duckhouse    Male
#
#    past_3_years_bike_related_purchases   age               job_title  \
# 0                                   93  64.0     Executive Secretary
# 1                                   81  37.0  Administrative Officer
# 2                                   33  56.0                     N/A
# 3                                   56  40.0           Senior Editor
# 4                                   35  51.0                     N/A
#
#   job_industry_category     wealth_segment deceased_indicator owns_car  \
# 0                Health      Mass Customer                 No      Yes
# 1    Financial Services      Mass Customer                 No      Yes
# ...

# %%
from sklearn.impute import KNNImputer
from sklearn.preprocessing import OneHotEncoder

# Drop unnecessary columns
temp_df = All_Customer_Details_df.drop(['customer_id', 'name', 'job_title', 'deceased_indicator', 'postcode', 'country', 'building_number', 'street_name'], axis=1)

# Separate numerical and categorical columns
numerical_cols = temp_df.select_dtypes(include='number').columns
categorical_cols = temp_df.select_dtypes(include='object').columns

# One-hot encode categorical columns (even though they have no missing values)
encoder = OneHotEncoder(sparse_output=False, drop='first')
encoded_categorical = pd.DataFrame(encoder.fit_transform(temp_df[categorical_cols]),
                                   columns=encoder.get_feature_names_out(categorical_cols),
                                   index=temp_df.index)

# Concatenate the numerical and one-hot encoded categorical columns
combined_data = pd.concat([temp_df[numerical_cols], encoded_categorical], axis=1)

# Impute missing values using KNNImputer on the combined data
imputer = KNNImputer(n_neighbors=3)
imputed_data = pd.DataFrame(imputer.fit_transform(combined_data),
                            columns=combined_data.columns,
                            index=combined_data.index)

# Extract the imputed numerical columns
imputed_numerical = imputed_data[numerical_cols]

# Update the original DataFrame with the imputed numerical values
All_Customer_Details_df[numerical_cols] = imputed_numerical
All_Customer_Details_df.head()
# Out:
#    customer_id                   name  gender  \
# 0            1      Laraine Medendorp  Female
# 1            2            Eli Bockman    Male
# 2            4                 Talbot    Male
# 3            5  Sheila-kathryn Calton  Female
# 4            6         Curr Duckhouse    Male
#
#    past_3_years_bike_related_purchases   age               job_title  \
# 0                                 93.0  64.0     Executive Secretary
# 1                                 81.0  37.0  Administrative Officer
# 2                                 33.0  56.0                     N/A
# 3                                 56.0  40.0           Senior Editor
# 4                                 35.0  51.0                     N/A
#
#   job_industry_category     wealth_segment deceased_indicator owns_car  \
# 0                Health      Mass Customer                 No      Yes
# 1    Financial Services      Mass Customer                 No      Yes
# ...

# %%
All_Customer_Details_df.isnull().sum()
# Out:
# customer_id                            0
# name                                   0
# gender                                 0
# past_3_years_bike_related_purchases    0
# age                                    0
# job_title                              0
# job_industry_category                  0
# wealth_segment                         0
# deceased_indicator                     0
# owns_car                               0
# tenure                                 0
# building_number                        0
# street_name                            0
# postcode                               0
# state                                  0
# country                                0
# property_valuation                     0
# dtype: int64

# %%
All_Customer_Details_df['past_3_years_bike_related_purchases'] = All_Customer_Details_df['past_3_years_bike_related_purchases'].astype(int)
All_Customer_Details_df['age'] = All_Customer_Details_df['age'].astype(int)
All_Customer_Details_df['tenure'] = All_Customer_Details_df['tenure'].astype(int)
All_Customer_Details_df['property_valuation'] = All_Customer_Details_df['property_valuation'].astype(int)

# %%
All_Customer_Details_df.shape
# Out:
# (4995, 17)

# %%
All_Customer_Details_df.head()
# Out:
#    customer_id                   name  gender  \
# 0            1      Laraine Medendorp  Female
# 1            2            Eli Bockman    Male
# 2            4                 Talbot    Male
# 3            5  Sheila-kathryn Calton  Female
# 4            6         Curr Duckhouse    Male
#
#    past_3_years_bike_related_purchases  age               job_title  \
# 0                                   93   64     Executive Secretary
# 1                                   81   37  Administrative Officer
# 2                                   33   56                     N/A
# 3                                   56   40           Senior Editor
# 4                                   35   51                     N/A
#
#   job_industry_category     wealth_segment deceased_indicator owns_car  \
# 0                Health      Mass Customer                 No      Yes
# 1    Financial Services      Mass Customer                 No      Yes
# ...

# %%
All_Customer_Details_df.to_csv('Final Sheets\customer_details.csv', index=False)
